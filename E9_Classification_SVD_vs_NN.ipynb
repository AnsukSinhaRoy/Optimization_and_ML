# %% [markdown]
# ## NN

# %%
#Generating dataset
import numpy as np
import pandas as pd
import time
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
from sklearn.datasets import make_circles
X, y = make_circles(100, factor=.1, noise=.1)
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='bwr')

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X,y,epochs=120,batch_size=1,validation_split=0.2)
#print(time.time() - start)
plt.plot(history.history['loss'])
# Out:
# Epoch 1/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5055 - loss: 0.6510 - val_accuracy: 0.4000 - val_loss: 0.6486
# Epoch 2/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5419 - loss: 0.6289 - val_accuracy: 0.4500 - val_loss: 0.6330
# Epoch 3/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5877 - loss: 0.6056 - val_accuracy: 0.5000 - val_loss: 0.6139
# Epoch 4/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6302 - loss: 0.5865 - val_accuracy: 0.6500 - val_loss: 0.5925
# Epoch 5/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7777 - loss: 0.5445 - val_accuracy: 0.6500 - val_loss: 0.5706
# Epoch 6/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8266 - loss: 0.5342 - val_accuracy: 0.8000 - val_loss: 0.5459
# Epoch 7/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8543 - loss: 0.4834 - val_accuracy: 0.8000 - val_loss: 0.5164
# Epoch 8/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9131 - loss: 0.4623 - val_accuracy: 0.8000 - val_loss: 0.4885
# Epoch 9/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8883 - loss: 0.4204 - val_accuracy: 0.9000 - val_loss: 0.4587
# Epoch 10/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9438 - loss: 0.3585 - val_accuracy: 0.9500 - val_loss: 0.4283
# Epoch 11/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9483 - loss: 0.3446 - val_accuracy: 1.0000 - val_loss: 0.3942
# Epoch 12/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9025 - loss: 0.3345 - val_accuracy: 1.0000 - val_loss: 0.3631
# Epoch 13/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9519 - loss: 0.2876 - val_accuracy: 1.0000 - val_loss: 0.3305
# Epoch 14/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.2937 - val_accuracy: 1.0000 - val_loss: 0.2989
# Epoch 15/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2403 - val_accuracy: 1.0000 - val_loss: 0.2654
# Epoch 16/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1857 - val_accuracy: 1.0000 - val_loss: 0.2326
# Epoch 17/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1738 - val_accuracy: 1.0000 - val_loss: 0.2022
# Epoch 18/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1682 - val_accuracy: 1.0000 - val_loss: 0.1750
# Epoch 19/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1546 - val_accuracy: 1.0000 - val_loss: 0.1497
# Epoch 20/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1032 - val_accuracy: 1.0000 - val_loss: 0.1244
# Epoch 21/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0980 - val_accuracy: 1.0000 - val_loss: 0.1042
# Epoch 22/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0639 - val_accuracy: 1.0000 - val_loss: 0.0859
# Epoch 23/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0732 - val_accuracy: 1.0000 - val_loss: 0.0714
# Epoch 24/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0635 - val_accuracy: 1.0000 - val_loss: 0.0594
# Epoch 25/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0455 - val_accuracy: 1.0000 - val_loss: 0.0492
# Epoch 26/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0332 - val_accuracy: 1.0000 - val_loss: 0.0411
# Epoch 27/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 0.0349
# Epoch 28/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0278 - val_accuracy: 1.0000 - val_loss: 0.0294
# Epoch 29/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0282 - val_accuracy: 1.0000 - val_loss: 0.0247
# Epoch 30/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0292 - val_accuracy: 1.0000 - val_loss: 0.0209
# Epoch 31/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 32/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 33/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 34/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 35/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 36/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 37/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 38/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 39/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 40/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 41/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 42/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 43/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 44/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 45/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 46/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 47/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 48/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 49/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 50/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 51/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 52/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 53/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 54/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.9846e-04 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 55/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 56/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 57/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 58/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.6021e-04 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 59/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 60/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.4469e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 61/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.4837e-04 - val_accuracy: 1.0000 - val_loss: 9.4639e-04
# Epoch 62/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.3099e-04 - val_accuracy: 1.0000 - val_loss: 8.9953e-04
# Epoch 63/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.6074e-04 - val_accuracy: 1.0000 - val_loss: 8.1689e-04
# Epoch 64/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.9722e-04 - val_accuracy: 1.0000 - val_loss: 7.8604e-04
# Epoch 65/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6978e-04 - val_accuracy: 1.0000 - val_loss: 7.5539e-04
# Epoch 66/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.5282e-04 - val_accuracy: 1.0000 - val_loss: 7.0130e-04
# Epoch 67/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.4684e-04 - val_accuracy: 1.0000 - val_loss: 6.7778e-04
# Epoch 68/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.5064e-04 - val_accuracy: 1.0000 - val_loss: 6.3399e-04
# Epoch 69/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.3873e-04 - val_accuracy: 1.0000 - val_loss: 5.7029e-04
# Epoch 70/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.9091e-04 - val_accuracy: 1.0000 - val_loss: 5.4468e-04
# Epoch 71/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.5030e-04 - val_accuracy: 1.0000 - val_loss: 5.1295e-04
# Epoch 72/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.1665e-04 - val_accuracy: 1.0000 - val_loss: 4.8794e-04
# Epoch 73/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.5161e-04 - val_accuracy: 1.0000 - val_loss: 4.4318e-04
# Epoch 74/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.6848e-04 - val_accuracy: 1.0000 - val_loss: 4.1089e-04
# Epoch 75/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.3885e-04 - val_accuracy: 1.0000 - val_loss: 3.7548e-04
# Epoch 76/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.6405e-04 - val_accuracy: 1.0000 - val_loss: 3.4787e-04
# Epoch 77/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.3039e-04 - val_accuracy: 1.0000 - val_loss: 3.2982e-04
# Epoch 78/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.2191e-04 - val_accuracy: 1.0000 - val_loss: 3.0483e-04
# Epoch 79/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4535e-04 - val_accuracy: 1.0000 - val_loss: 2.8213e-04
# Epoch 80/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.0570e-04 - val_accuracy: 1.0000 - val_loss: 2.6226e-04
# Epoch 81/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.5368e-04 - val_accuracy: 1.0000 - val_loss: 2.4571e-04
# Epoch 82/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.3993e-04 - val_accuracy: 1.0000 - val_loss: 2.2948e-04
# Epoch 83/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.9986e-04 - val_accuracy: 1.0000 - val_loss: 2.2192e-04
# Epoch 84/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1009e-04 - val_accuracy: 1.0000 - val_loss: 2.0427e-04
# Epoch 85/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.2405e-04 - val_accuracy: 1.0000 - val_loss: 1.9456e-04
# Epoch 86/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4058e-04 - val_accuracy: 1.0000 - val_loss: 1.7823e-04
# Epoch 87/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.5446e-04 - val_accuracy: 1.0000 - val_loss: 1.7053e-04
# Epoch 88/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.3287e-04 - val_accuracy: 1.0000 - val_loss: 1.6472e-04
# Epoch 89/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0006e-04 - val_accuracy: 1.0000 - val_loss: 1.5369e-04
# Epoch 90/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.7576e-04 - val_accuracy: 1.0000 - val_loss: 1.4139e-04
# Epoch 91/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.5937e-04 - val_accuracy: 1.0000 - val_loss: 1.3737e-04
# Epoch 92/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.6873e-05 - val_accuracy: 1.0000 - val_loss: 1.3305e-04
# Epoch 93/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.2395e-04 - val_accuracy: 1.0000 - val_loss: 1.2002e-04
# Epoch 94/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.6148e-04 - val_accuracy: 1.0000 - val_loss: 1.1371e-04
# Epoch 95/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.3102e-04 - val_accuracy: 1.0000 - val_loss: 1.0621e-04
# Epoch 96/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.9395e-05 - val_accuracy: 1.0000 - val_loss: 9.7972e-05
# Epoch 97/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.1950e-05 - val_accuracy: 1.0000 - val_loss: 9.5961e-05
# Epoch 98/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.0166e-05 - val_accuracy: 1.0000 - val_loss: 9.1748e-05
# Epoch 99/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.5343e-05 - val_accuracy: 1.0000 - val_loss: 9.5459e-05
# Epoch 100/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.3633e-05 - val_accuracy: 1.0000 - val_loss: 8.6588e-05
# Epoch 101/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.9398e-05 - val_accuracy: 1.0000 - val_loss: 8.2394e-05
# Epoch 102/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.8777e-05 - val_accuracy: 1.0000 - val_loss: 7.8844e-05
# Epoch 103/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.9842e-05 - val_accuracy: 1.0000 - val_loss: 7.4308e-05
# Epoch 104/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.4940e-05 - val_accuracy: 1.0000 - val_loss: 6.8212e-05
# Epoch 105/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.7602e-05 - val_accuracy: 1.0000 - val_loss: 6.3343e-05
# Epoch 106/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.4457e-05 - val_accuracy: 1.0000 - val_loss: 6.0907e-05
# Epoch 107/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.1446e-05 - val_accuracy: 1.0000 - val_loss: 5.4546e-05
# Epoch 108/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.9756e-05 - val_accuracy: 1.0000 - val_loss: 5.2558e-05
# Epoch 109/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.1626e-05 - val_accuracy: 1.0000 - val_loss: 5.4470e-05
# Epoch 110/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.4734e-05 - val_accuracy: 1.0000 - val_loss: 5.0205e-05
# Epoch 111/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.2262e-05 - val_accuracy: 1.0000 - val_loss: 4.6215e-05
# Epoch 112/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.3076e-05 - val_accuracy: 1.0000 - val_loss: 4.2476e-05
# Epoch 113/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.4506e-05 - val_accuracy: 1.0000 - val_loss: 3.9825e-05
# Epoch 114/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.6784e-05 - val_accuracy: 1.0000 - val_loss: 3.7667e-05
# Epoch 115/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8250e-05 - val_accuracy: 1.0000 - val_loss: 3.5238e-05
# Epoch 116/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.9268e-05 - val_accuracy: 1.0000 - val_loss: 3.3341e-05
# Epoch 117/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.9551e-05 - val_accuracy: 1.0000 - val_loss: 3.1020e-05
# Epoch 118/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8403e-05 - val_accuracy: 1.0000 - val_loss: 2.8238e-05
# Epoch 119/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.1717e-05 - val_accuracy: 1.0000 - val_loss: 2.6787e-05
# Epoch 120/120
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8630e-05 - val_accuracy: 1.0000 - val_loss: 2.6707e-05

# %% [markdown]
# ## SVM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from mpl_toolkits import mplot3d
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from matplotlib.colors import ListedColormap

# %%
#Generating dataset
from sklearn.datasets import make_circles
X, y = make_circles(100, factor=.1, noise=.1)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='bwr')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
classifier = SVC(kernel="linear")
classifier.fit(X_train, y_train.ravel())
y_pred = classifier.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

# %%
zero_one_colourmap = ListedColormap(('blue', 'red'))
def plot_decision_boundary(X, y, clf):
    X_set, y_set = X, y
    X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1,
                                 stop = X_set[:, 0].max() + 1,
                                 step = 0.01),
                       np.arange(start = X_set[:, 1].min() - 1,
                                 stop = X_set[:, 1].max() + 1,
                                 step = 0.01))

    plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
                                             X2.ravel()]).T).reshape(X1.shape),
               alpha = 0.75,
               cmap = zero_one_colourmap)
    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())
    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = (zero_one_colourmap)(i), label = j)
    plt.title('SVM Decision Boundary')
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.legend()
    return plt.show()

plot_decision_boundary(X, y, classifier)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9868\709163680.py:18: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],

# %%
def plot_3d_plot(X, y):
    r = np.exp(-(X ** 2).sum(1))
    ax = plt.subplot(projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], r, c=y, s=100, cmap='bwr')
    ax.set_xlabel('X1')
    ax.set_ylabel('X2')
    ax.set_zlabel('y')
    return ax

plot_3d_plot(X,y)

rbf_classifier = SVC(kernel="rbf")
rbf_classifier.fit(X_train, y_train)
y_pred = rbf_classifier.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
plot_decision_boundary(X, y, rbf_classifier)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9868\709163680.py:18: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
